# %%
import requests
from bs4 import BeautifulSoup

page = requests.get("https://finance.yahoo.com/quote/BBAS3.SA/history?p=BBAS3.SA")
page

soup = BeautifulSoup(page.text,'html.parser')


table = soup.findAll('table')

table = table[0]
table
for row in table.findAll('tr'):
    new_row= []
    for cell in row.findAll('td'):
        new_row.append(cell.get_text().strip())
    print(new_row)
# Out:
# []
# ['Jul 24, 2018', '33.20', '33.42', '32.99', '33.12', '33.12', '934,400']
# ['Jul 23, 2018', '33.00', '33.20', '32.63', '32.78', '32.78', '5,622,900']
# ['Jul 20, 2018', '32.50', '33.33', '32.07', '33.00', '33.00', '19,568,500']
# ['Jul 19, 2018', '31.17', '31.34', '30.37', '31.34', '31.34', '27,335,300']
# ['Jul 18, 2018', '31.80', '32.23', '31.39', '31.62', '31.62', '12,842,500']
# ['Jul 17, 2018', '30.63', '32.10', '30.57', '31.82', '31.82', '11,575,800']
# ['Jul 16, 2018', '31.08', '31.37', '30.45', '30.79', '30.79', '8,889,800']
# ['Jul 13, 2018', '30.30', '31.13', '30.16', '31.13', '31.13', '10,064,100']
# ['Jul 12, 2018', '29.90', '30.54', '29.90', '30.36', '30.36', '9,964,000']
# ['Jul 11, 2018', '28.95', '29.98', '28.71', '29.79', '29.79', '14,568,700']
# ['Jul 10, 2018', '29.90', '30.21', '29.00', '29.21', '29.21', '14,625,100']
# ['Jul 09, 2018', '29.46', '29.46', '29.46', '29.46', '29.46', '-']
# ...

# %%
import requests
from bs4 import BeautifulSoup

page = requests.get("https://finance.yahoo.com/quote/BBAS3.SA/history?p=BBAS3.SA")
page

soup = BeautifulSoup(page.text,'html.parser')


table = soup.findAll('table')

table = table[0]
table
for row in table.findAll('tr'):
    new_row= []
    for cell in row.findAll('td'):
        new_row.append(cell.get_text().strip())
    print(new_row)
# Out:
# []
# ['Jul 24, 2018', '33.20', '33.42', '32.99', '33.09', '33.09', '942,200']
# ['Jul 23, 2018', '33.00', '33.20', '32.63', '32.78', '32.78', '5,622,900']
# ['Jul 20, 2018', '32.50', '33.33', '32.07', '33.00', '33.00', '19,568,500']
# ['Jul 19, 2018', '31.17', '31.34', '30.37', '31.34', '31.34', '27,335,300']
# ['Jul 18, 2018', '31.80', '32.23', '31.39', '31.62', '31.62', '12,842,500']
# ['Jul 17, 2018', '30.63', '32.10', '30.57', '31.82', '31.82', '11,575,800']
# ['Jul 16, 2018', '31.08', '31.37', '30.45', '30.79', '30.79', '8,889,800']
# ['Jul 13, 2018', '30.30', '31.13', '30.16', '31.13', '31.13', '10,064,100']
# ['Jul 12, 2018', '29.90', '30.54', '29.90', '30.36', '30.36', '9,964,000']
# ['Jul 11, 2018', '28.95', '29.98', '28.71', '29.79', '29.79', '14,568,700']
# ['Jul 10, 2018', '29.90', '30.21', '29.00', '29.21', '29.21', '14,625,100']
# ['Jul 09, 2018', '29.46', '29.46', '29.46', '29.46', '29.46', '-']
# ...
