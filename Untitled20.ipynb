# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
website = 'http://www.espn.com/college-sports/football/recruiting/databaseresults/_/sportid/24/class/2006/sort/school/starsfilter/GT/ratingfilter/GT/statuscommit/Commitments/statusuncommit/Uncommited'

# %%
data = pd.read_html(website)
page1 = data[0]
page1
# Out:
#                                           0  \
# 0                                      NAME
# 1    Jermaine WilliamsVideo | Scouts Report
# 2         Justin TryonVideo | Scouts Report
# 3        Garrett JudahVideo | Scouts Report
# 4      Lance EvbuomwanVideo | Scouts Report
# 5        Chris BaloneyVideo | Scouts Report
# 6        Jeff BereuterVideo | Scouts Report
# 7        Saia FalaholaVideo | Scouts Report
# 8         Zach NiusuluVideo | Scouts Report
# 9    Angelo RichardsonVideo | Scouts Report
# 10          Jon HargisVideo | Scouts Report
# 11        Rodney GlassVideo | Scouts Report
# 12          Ryan McFoyVideo | Scouts Report
# 13    Andrew BerryhillVideo | Scouts Report
# 14       Kyle WilliamsVideo | Scouts Report
# 15      Martin TevaseuVideo | Scouts Report
# 16     Jamarr RobinsonVideo | Scouts Report
# 17      Danny SullivanVideo | Scouts Report
# 18         Ryan TorainVideo | Scouts Report
# 19     Brantwon BowserVideo | Scouts Report
# ...
